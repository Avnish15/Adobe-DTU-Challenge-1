# %% [markdown]
# <a href="https://colab.research.google.com/github/Avnish15/Adobe-DTU-Challenge-1/blob/main/Adobe_DTU_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing librararies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Loading the dataset

# %%
df = pd.read_excel(r"/content/drive/MyDrive/Adobe-DTU-Challenge/Adobe-DTU-Challenge.xlsx")
df
# Out:
#             id                 date  likes  \
# 0            1  2020-12-12 00:47:00      1
# 1            2  2018-06-30 10:04:20   2750
# 2            3  2020-09-29 19:47:28     57
# 3            4  2020-10-01 11:40:09    152
# 4            5  2018-10-19 14:30:46     41
# ...        ...                  ...    ...
# 299995  299996  2019-09-07 16:18:10      0
# 299996  299997  2018-02-23 11:24:36     46
# 299997  299998  2020-11-11 20:18:15    261
# 299998  299999  2019-10-29 10:44:00    119
# 299999  300000  2018-08-26 01:19:09    714
#
#                                                   content        username  \
# 0       Spend your weekend morning with a Ham, Egg, an...    TimHortonsPH
# 1       Watch rapper <mention> freestyle for over an H...       IndyMusic
# 2       Canadian Armenian community demands ban on mil...       CBCCanada
# 3       1st in Europe to be devastated by COVID-19, It...  MKWilliamsRome
# ...

# %% [markdown]
# ## 2. Exploring the dataset

# %%
df.info()         #Retriving the basic information of the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                300000 non-null  int64
#  1   date              300000 non-null  object
#  2   likes             300000 non-null  int64
#  3   content           300000 non-null  object
#  4   username          300000 non-null  object
#  5   media             300000 non-null  object
#  6   inferred company  300000 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 16.0+ MB

# %%
df.head()    # Retriving the top 5 colums of the data set
# Out:
#    id                 date  likes  \
# 0   1  2020-12-12 00:47:00      1
# 1   2  2018-06-30 10:04:20   2750
# 2   3  2020-09-29 19:47:28     57
# 3   4  2020-10-01 11:40:09    152
# 4   5  2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  Spend your weekend morning with a Ham, Egg, an...    TimHortonsPH
# 1  Watch rapper <mention> freestyle for over an H...       IndyMusic
# 2  Canadian Armenian community demands ban on mil...       CBCCanada
# 3  1st in Europe to be devastated by COVID-19, It...  MKWilliamsRome
# 4  Congratulations to Pauletha Butts of <mention>...           BGISD
#
#                                                media inferred company
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 2  [Photo(previewUrl='https://pbs.twimg.com/media...              cbc
# ...

# %%
df.tail()   #Retriving the bottom 5 columns of data set
# Out:
#             id                 date  likes  \
# 299995  299996  2019-09-07 16:18:10      0
# 299996  299997  2018-02-23 11:24:36     46
# 299997  299998  2020-11-11 20:18:15    261
# 299998  299999  2019-10-29 10:44:00    119
# 299999  300000  2018-08-26 01:19:09    714
#
#                                                   content        username  \
# 299995  Barcelona Star Expected To Return Against Vale...  IndependentNGR
# 299996  Kjeld Nuis of #NED is golden again... This tim...     CBCOlympics
# 299997  Grateful 🙌🏾 to have <mention> officially join ...   TeamCoachBuzz
# 299998  The US Air Force's mysterious space plane just...     Independent
# 299999  In 1967, he was shot down over Vietnam. By 200...            cnni
#
#                                                     media inferred company
# 299995  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 299996  [Video(thumbnailUrl='https://pbs.twimg.com/med...              cbc
# ...

# %%
df.describe()     #Retriving the description of the numeric columns of the data set
# Out:
#                   id          likes
# count  300000.000000  300000.000000
# mean   150000.500000     773.364793
# std     86602.684716    4931.463419
# min         1.000000       0.000000
# 25%     75000.750000       3.000000
# 50%    150000.500000      76.000000
# 75%    225000.250000     364.000000
# max    300000.000000  560193.000000

# %%
df.shape    # shows the no of rows and columns in  the data set
# Out:
# (300000, 7)

# %%
df.size         # it gives the combination of rows and column size (rows * columns)
# Out:
# 2100000

# %% [markdown]
# ## 3. Cleaning and preparing the dataset

# %%
df.isnull().sum()                #Evaluate any null values in the data set
# as it has all zeros so there is no null values
# Out:
# id                  0
# date                0
# likes               0
# content             0
# username            0
# media               0
# inferred company    0
# dtype: int64

# %% [markdown]
# ### NOTE: FROM ABOVE DESCRIPTION THERE IS NO MISSING VALUES

# %%
mask = df.duplicated()   # checking any duplicate values recites by whole data set
mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 299995    False
# 299996    False
# 299997    False
# 299998    False
# 299999    False
# Length: 300000, dtype: bool

# %%
df[mask]
# Out:
# Empty DataFrame
# Columns: [id, date, likes, content, username, media, inferred company]
# Index: []

# %% [markdown]
# ### NOTE: FROM ABOVE DESCRIPTION THERE IS NO DUPLICATED RECORDS

# %%
df.duplicated(subset=(['username','content'])).sum()   # Checking any duplicate values by few columns data
# Out:
# 17542

# %%
df.duplicated(subset=(['username','content', 'media'])).sum()
# Out:
# 2941

# %%
df.duplicated(subset=(['username','content', 'media', 'inferred company'])).sum()
# Out:
# 2395

# %%
df.duplicated(subset=(['username','content', 'media', 'inferred company', 'date'])).sum()
# Out:
# 1

# %% [markdown]
# ##### Users have posted same content, even some have shared same media and belong to the same company on different dates

# %%
# Converting time to timestamp for better readability
df['date'] = pd.to_datetime(df['date'])
#df['day'] = df['date'].dt.day
#df.drop(columns = ['day'], inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                300000 non-null  int64
#  1   date              300000 non-null  datetime64[ns]
#  2   likes             300000 non-null  int64
#  3   content           300000 non-null  object
#  4   username          300000 non-null  object
#  5   media             300000 non-null  object
#  6   inferred company  300000 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 16.0+ MB

# %% [markdown]
# ### Processing media url's

# %%
def extract_urls_and_types(link):
    # Extract URLs and types
    if link[1:6] == 'Photo':
        link_type = 'Photo'
    elif link[1:4] == 'Gif':
        link_type = 'Gif'
    elif link[1:6] == 'Video':
        link_type = 'Video'
    else:
        link_type = None

    return link_type

# %%
df['media_type'] = df['media'].apply(lambda text: extract_urls_and_types(text))

# %%
df.head()
# Out:
#    id                date  likes  \
# 0   1 2020-12-12 00:47:00      1
# 1   2 2018-06-30 10:04:20   2750
# 2   3 2020-09-29 19:47:28     57
# 3   4 2020-10-01 11:40:09    152
# 4   5 2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  Spend your weekend morning with a Ham, Egg, an...    TimHortonsPH
# 1  Watch rapper <mention> freestyle for over an H...       IndyMusic
# 2  Canadian Armenian community demands ban on mil...       CBCCanada
# 3  1st in Europe to be devastated by COVID-19, It...  MKWilliamsRome
# 4  Congratulations to Pauletha Butts of <mention>...           BGISD
#
#                                                media inferred company  \
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 2  [Photo(previewUrl='https://pbs.twimg.com/media...              cbc
# ...

# %%
df['media_type'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### There are only three Kinds of media : 1. Video 2. Photo 3. Gif

# %% [markdown]
# ## Text Processing

# %%
import re
import nltk
import spacy
import string

# %%
# Calculating the length of the content
df['content_length'] = df['content'].apply(lambda text : len(text))
df.head()
# Out:
#    id                date  likes  \
# 0   1 2020-12-12 00:47:00      1
# 1   2 2018-06-30 10:04:20   2750
# 2   3 2020-09-29 19:47:28     57
# 3   4 2020-10-01 11:40:09    152
# 4   5 2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  Spend your weekend morning with a Ham, Egg, an...    TimHortonsPH
# 1  Watch rapper <mention> freestyle for over an H...       IndyMusic
# 2  Canadian Armenian community demands ban on mil...       CBCCanada
# 3  1st in Europe to be devastated by COVID-19, It...  MKWilliamsRome
# 4  Congratulations to Pauletha Butts of <mention>...           BGISD
#
#                                                media inferred company  \
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 2  [Photo(previewUrl='https://pbs.twimg.com/media...              cbc
# ...

# %%
# Lower Casing : Convert the input text into same casing format
df['content'] = df['content'].str.lower()
df.head()
# Out:
#    id                date  likes  \
# 0   1 2020-12-12 00:47:00      1
# 1   2 2018-06-30 10:04:20   2750
# 2   3 2020-09-29 19:47:28     57
# 3   4 2020-10-01 11:40:09    152
# 4   5 2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  spend your weekend morning with a ham, egg, an...    TimHortonsPH
# 1  watch rapper <mention> freestyle for over an h...       IndyMusic
# 2  canadian armenian community demands ban on mil...       CBCCanada
# 3  1st in europe to be devastated by covid-19, it...  MKWilliamsRome
# 4  congratulations to pauletha butts of <mention>...           BGISD
#
#                                                media inferred company  \
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 2  [Photo(previewUrl='https://pbs.twimg.com/media...              cbc
# ...

# %%
# Punctuations Removal : a text standardization process
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

df["content"] = df['content'].apply(lambda text: remove_punctuation(text))
df.head()
# Out:
#    id                date  likes  \
# 0   1 2020-12-12 00:47:00      1
# 1   2 2018-06-30 10:04:20   2750
# 2   3 2020-09-29 19:47:28     57
# 3   4 2020-10-01 11:40:09    152
# 4   5 2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  spend your weekend morning with a ham egg and ...    TimHortonsPH
# 1  watch rapper mention freestyle for over an hou...       IndyMusic
# 2  canadian armenian community demands ban on mil...       CBCCanada
# 3  1st in europe to be devastated by covid19 ital...  MKWilliamsRome
# 4  congratulations to pauletha butts of mention s...           BGISD
#
#                                                media inferred company  \
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 2  [Photo(previewUrl='https://pbs.twimg.com/media...              cbc
# ...

# %%
# Stopword Removal : words in a language like 'the', 'a' and so on  can be removed from the
# text most of the times, as they don't provide valuable information for downstream analysis.

nltk.download('stopwords')

from nltk.corpus import stopwords

STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

df["content"] = df["content"].apply(lambda text: remove_stopwords(text))
df.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#    id                date  likes  \
# 0   1 2020-12-12 00:47:00      1
# 1   2 2018-06-30 10:04:20   2750
# 2   3 2020-09-29 19:47:28     57
# 3   4 2020-10-01 11:40:09    152
# 4   5 2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  spend weekend morning ham egg cheese wrap pair...    TimHortonsPH
# 1  watch rapper mention freestyle hour hyperlink ...       IndyMusic
# 2  canadian armenian community demands ban milita...       CBCCanada
# 3  1st europe devastated covid19 italy redoubled ...  MKWilliamsRome
# 4  congratulations pauletha butts mention present...           BGISD
#
#                                                media inferred company  \
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# ...

# %%
# Frequent Words
from collections import Counter
cnt = Counter()
for text in df['content'].values:
    for word in text.split():
        cnt[word] += 1

cnt.most_common(10)
# Out:
# [('hyperlink', 464779),
#  ('mention', 128232),
#  ('new', 23898),
#  ('amp', 19794),
#  ('get', 18654),
#  ('us', 17495),
#  ('one', 12502),
#  ('today', 12165),
#  ('learn', 11957),
#  ('time', 11239)]

# %%
# Rare Words
n_rare_words = 10
RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-n_rare_words-1:-1]])
RAREWORDS
# Out:
# {'biff',
#  'commonwealthgames',
#  'haavard',
#  'hundredths',
#  'kjeld',
#  'lorentzens',
#  'menah',
#  'nuis',
#  'partsofspeech',
#  '━━╋━━┛'}

# %%
# Stemming : If there are two words in the corpus walks and walking, then stemming will stem the suffix to make them walk.
from nltk.stem.porter import PorterStemmer

stemmer = PorterStemmer()
def stem_words(text):
    return " ".join([stemmer.stem(word) for word in text.split()])

df["content"] = df["content"].apply(lambda text: stem_words(text))
df.head()
# Out:
#    id                date  likes  \
# 0   1 2020-12-12 00:47:00      1
# 1   2 2018-06-30 10:04:20   2750
# 2   3 2020-09-29 19:47:28     57
# 3   4 2020-10-01 11:40:09    152
# 4   5 2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  spend weekend morn ham egg chees wrap pair swe...    TimHortonsPH
# 1  watch rapper mention freestyl hour hyperlink h...       IndyMusic
# 2  canadian armenian commun demand ban militari d...       CBCCanada
# 3  1st europ devast covid19 itali redoubl effort ...  MKWilliamsRome
# 4  congratul pauletha butt mention present beyond...           BGISD
#
#                                                media inferred company  \
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 2  [Photo(previewUrl='https://pbs.twimg.com/media...              cbc
# ...

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# ...

# %%
def remove_emoji(string):
  emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
  return emoji_pattern.sub(r'', string)

df['content'] = df['content'].apply(lambda text : remove_emoji(text))
df.head()
# Out:
#    id                date  likes  \
# 0   1 2020-12-12 00:47:00      1
# 1   2 2018-06-30 10:04:20   2750
# 2   3 2020-09-29 19:47:28     57
# 3   4 2020-10-01 11:40:09    152
# 4   5 2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  spend weekend morn ham egg chees wrap pair swe...    TimHortonsPH
# 1  watch rapper mention freestyl hour hyperlink h...       IndyMusic
# 2  canadian armenian commun demand ban militari d...       CBCCanada
# 3  1st europ devast covid19 itali redoubl effort ...  MKWilliamsRome
# 4  congratul pauletha butt mention present beyond...           BGISD
#
#                                                media inferred company  \
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 2  [Photo(previewUrl='https://pbs.twimg.com/media...              cbc
# ...

# %%
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

df['content'] = df['content'].apply(lambda text : remove_urls(text))
df.head()
# Out:
#    id                date  likes  \
# 0   1 2020-12-12 00:47:00      1
# 1   2 2018-06-30 10:04:20   2750
# 2   3 2020-09-29 19:47:28     57
# 3   4 2020-10-01 11:40:09    152
# 4   5 2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  spend weekend morn ham egg chees wrap pair swe...    TimHortonsPH
# 1  watch rapper mention freestyl hour hyperlink h...       IndyMusic
# 2  canadian armenian commun demand ban militari d...       CBCCanada
# 3  1st europ devast covid19 itali redoubl effort ...  MKWilliamsRome
# 4  congratul pauletha butt mention present beyond...           BGISD
#
#                                                media inferred company  \
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 2  [Photo(previewUrl='https://pbs.twimg.com/media...              cbc
# ...

# %%
def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

df['content'] = df['content'].apply(lambda text : remove_html(text))
df.head()
# Out:
#    id                date  likes  \
# 0   1 2020-12-12 00:47:00      1
# 1   2 2018-06-30 10:04:20   2750
# 2   3 2020-09-29 19:47:28     57
# 3   4 2020-10-01 11:40:09    152
# 4   5 2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  spend weekend morn ham egg chees wrap pair swe...    TimHortonsPH
# 1  watch rapper mention freestyl hour hyperlink h...       IndyMusic
# 2  canadian armenian commun demand ban militari d...       CBCCanada
# 3  1st europ devast covid19 itali redoubl effort ...  MKWilliamsRome
# 4  congratul pauletha butt mention present beyond...           BGISD
#
#                                                media inferred company  \
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 2  [Photo(previewUrl='https://pbs.twimg.com/media...              cbc
# ...

# %%
df.to_excel('my_dataframe.xlsx', index=False)

# %% [markdown]
# ### Univariate Analysis

# %%
df = pd.read_excel(r"/content/drive/MyDrive/Adobe-DTU-Challenge/my_dataframe.xlsx")
df
# Out:
#             id                date  likes  \
# 0            1 2020-12-12 00:47:00      1
# 1            2 2018-06-30 10:04:20   2750
# 2            3 2020-09-29 19:47:28     57
# 3            4 2020-10-01 11:40:09    152
# 4            5 2018-10-19 14:30:46     41
# ...        ...                 ...    ...
# 299995  299996 2019-09-07 16:18:10      0
# 299996  299997 2018-02-23 11:24:36     46
# 299997  299998 2020-11-11 20:18:15    261
# 299998  299999 2019-10-29 10:44:00    119
# 299999  300000 2018-08-26 01:19:09    714
#
#                                                   content        username  \
# 0       spend weekend morning ham egg cheese wrap pair...    TimHortonsPH
# 1       watch rapper mention freestyle hour hyperlink ...       IndyMusic
# 2       canadian armenian community demand ban militar...       CBCCanada
# 3       1st europe devastate covid19 italy redouble ef...  MKWilliamsRome
# 4       congratulation pauletha butts mention present ...           BGISD
# ...

# %%
output_df = pd.DataFrame(columns=['count', 'Missing', 'Unique', 'Dtype', 'Numeric', 'Mode', 'Mean', 'Min', '25%', 'Median', '75%', 'Max', 'std', 'Skew', 'Kurt'])

for col in df :
  if pd.api.types.is_numeric_dtype(df[col]) :
    output_df.loc[col] = [df[col].count(), df[col].isnull().sum(), df[col].nunique(), df[col].dtype, pd.api.types.is_numeric_dtype(df[col]),
                          df[col].mode().values[0], df[col].mean(), df[col].min(), df[col].quantile(0.25), df[col].median(), df[col].quantile(0.75),
                          df[col].max(), df[col].std(), df[col].skew(), df[col].kurt()]
  else :
    output_df.loc[col] = [df[col].count(), df[col].isnull().sum(), df[col].nunique(), df[col].dtype, pd.api.types.is_numeric_dtype(df[col]),
                          df[col].mode().values[0], '-', '-', '-', '-', '-', '-', '-', '-', '-']

output_df = output_df.sort_values(by = ['Numeric', 'Skew', 'Unique'], ascending = False)
output_df
# Out:
#                    count  Missing  Unique           Dtype  Numeric  \
# likes             300000        0   11015           int64     True
# content_length    300000        0     313           int64     True
# id                300000        0  300000           int64     True
# media             300000        0  295266          object    False
# date              300000        0  292301  datetime64[ns]    False
# stemmed_content   300000        0  276478          object    False
# content           300000        0  276246          object    False
# username          300000        0    2449          object    False
# inferred company  300000        0     220          object    False
# media_type        300000        0       3          object    False
#
#                                                                Mode  \
# likes                                                             0
# content_length                                                   83
# ...

# %% [markdown]
# **1.**In the case of likes, the skewness being significantly positive suggests that the distribution of values in the 'likes' column is heavily weighted towards higher numbers.

# %% [markdown]
# **2.**A high kurtosis value like 2638.880985 indicates that the distribution has heavy tails and a pronounced peak.

# %% [markdown]
# **3.**A skewness of 0.38716 indicates a moderate positive skew, meaning the data is slightly skewed towards higher values but not excessively so

# %% [markdown]
# **4.**a kurtosis of -0.917202 suggests that the data has fewer extreme values (outliers) and is less peaked than a normal distribution

# %% [markdown]
# **5.** "independent" has maximum number of tweets, and it primarily uses IndependentNGR username

# %% [markdown]
# **6.** Photo is the most widely used media type.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

#sampled_df = df.sample(n=10000, random_state=42)

sns.histplot(data=df, x='likes', ax=ax, kde=False, color='skyblue', bins=30)
sns.histplot(data=df, x='likes', ax=ax, kde=True, color='salmon', linewidth=2)

ax.set_xlabel('likes')
ax.set_ylabel('Count')
ax.set_title(f'Histogram and KDE Plot of likes')

ax.legend(['Histogram', 'KDE Plot'])

plt.show()

# %% [markdown]
# Note : Shows high value of skew

# %%
fig, ax = plt.subplots(figsize=(10, 6))

#sampled_df = df.sample(n=10000, random_state=42)

sns.histplot(data=df, x='content_length', ax=ax, kde=False, color='skyblue', bins=30)
sns.histplot(data=df, x='content_length', ax=ax, kde=True, color='salmon', linewidth=2)

ax.set_xlabel('content_length')
ax.set_ylabel('Count')
ax.set_title(f'Histogram and KDE Plot of content_length')

ax.legend(['Histogram', 'KDE Plot'])

plt.show()

# %%
category_freq = df['media_type'].value_counts()

plt.figure(figsize=(10, 6))
category_freq.plot(kind='bar', color='skyblue')
plt.xlabel('media_type')
plt.ylabel('Frequency')
plt.title('Frequency of media')
plt.xticks(rotation=0)
plt.show()

# %%
category_freq = df['username'].value_counts()

plt.figure(figsize=(10, 6))
category_freq.plot(kind='bar', color='skyblue')
plt.xlabel('username')
plt.ylabel('Frequency')
plt.title('Frequency of username')
plt.xticks([])
plt.show()

# %%
category_freq = df['inferred company'].value_counts()

plt.figure(figsize=(10, 6))
category_freq.plot(kind='bar', color='skyblue')
plt.xlabel('inferred company')
plt.ylabel('Frequency')
plt.title('Frequency of inferred company')
plt.xticks([])
plt.show()

# %% [markdown]
# ### Word Cloud Analysis

# %%
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(cnt)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axis
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
from scipy import stats

# Pearson Test
output_df = pd.DataFrame(columns=['Correlation coefficient', 'p-value'])

for col in df :
  if not col == 'likes' :
    if df[col].isnull().sum() == 0 :
      if pd.api.types.is_numeric_dtype(df[col]) :
        r, p = stats.pearsonr(df['likes'], df[col])
        output_df.loc[col] = [round(r, 5), round(p, 6)]


output_df.reindex(output_df['Correlation coefficient'].abs().sort_values(ascending = False).index)
# Out:
#                 Correlation coefficient   p-value
# content_length                 -0.01576  0.000000
# id                              0.00175  0.336862

# %% [markdown]
# ##### 1. It suggests that there is almost no linear relationship between the content length and likes. And it is statistically significant since p is very small.

# %%
# Extracting features from timestamp object
df['day'] = df['date'].dt.day
df['week'] = df['date'].dt.isocalendar().week
df['hour'] = df['date'].dt.hour
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year
df.head()
# Out:
#    id                date  likes  \
# 0   1 2020-12-12 00:47:00      1
# 1   2 2018-06-30 10:04:20   2750
# 2   3 2020-09-29 19:47:28     57
# 3   4 2020-10-01 11:40:09    152
# 4   5 2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  spend weekend morning ham egg cheese wrap pair...    TimHortonsPH
# 1  watch rapper mention freestyle hour hyperlink ...       IndyMusic
# 2  canadian armenian community demand ban militar...       CBCCanada
# 3  1st europe devastate covid19 italy redouble ef...  MKWilliamsRome
# 4  congratulation pauletha butts mention present ...           BGISD
#
#                                                media inferred company  \
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 2  [Photo(previewUrl='https://pbs.twimg.com/media...              cbc
# ...

# %%
output_df = pd.DataFrame(columns=['F-statistic', 'p-value'])

Categorical_columns = ['media_type', 'hour', 'day', 'week', 'month', 'year', 'username', 'inferred company']

for col in Categorical_columns :

  groups = df[col].unique()
  df_grouped = df.groupby(col)
  group_labels = []
  for g in groups :
    g_list = df_grouped.get_group(g)
    group_labels.append(g_list['likes'])
  f, p = stats.f_oneway(*group_labels)
  output_df.loc[col] = [round(f, 5), round(p, 6)]


output_df.reindex(output_df['F-statistic'].abs().sort_values(ascending = False).index)
# Out:
#                   F-statistic   p-value
# media_type          755.71732  0.000000
# inferred company    213.78312  0.000000
# year                 54.21034  0.000000
# username             30.41404  0.000000
# hour                 12.78484  0.000000
# month                11.13988  0.000000
# week                  3.99982  0.000000
# day                   1.68253  0.011066

# %% [markdown]
# ##### High differences between group means of ['media_type', 'year', 'hour', 'month'] column is observed and they are highly unlikely to be due to random chance.

# %% [markdown]
# ##### We can drop rest of the columns i.e week and day

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x='content_length', y='likes', color='blue', label='Data Points')

# Add title and labels
plt.title('pearson correlation')
plt.xlabel('content_length')
plt.ylabel('likes')

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### No direct linear relation between content_length and likes

# %%
plt.figure(figsize=(8, 6))

sns.boxplot(data=df, x='media_type', y='likes')

plt.title('media_type vs likes')
plt.xlabel('media_type')
plt.ylabel('likes')

plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.violinplot(data=df, x='media_type', y='likes')

plt.title('media_type vs likes')
plt.xlabel('media_type')
plt.ylabel('likes')

plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.boxplot(data=df, x='year', y='likes')

plt.title('year vs likes')
plt.xlabel('year')
plt.ylabel('likes')

plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.violinplot(data=df, x='year', y='likes')

plt.title('year vs likes')
plt.xlabel('year')
plt.ylabel('likes')

plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.boxplot(data=df, x='hour', y='likes')

plt.title('hour vs likes')
plt.xlabel('hour')
plt.ylabel('likes')

plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.violinplot(data=df, x='hour', y='likes')

plt.title('hour vs likes')
plt.xlabel('hour')
plt.ylabel('likes')

plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.boxplot(data=df, x='month', y='likes')

plt.title('month vs likes')
plt.xlabel('month')
plt.ylabel('likes')

plt.show()

# %%
plt.figure(figsize=(16, 6))

sns.boxplot(data=df, x='week', y='likes')

plt.title('week vs likes')
plt.xlabel('week')
plt.ylabel('likes')

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(data=df, x='day', y='likes')

plt.title('day vs likes')
plt.xlabel('day')
plt.ylabel('likes')

plt.show()

# %%
grouped_data = df.groupby(['media_type'])['likes'].mean().reset_index()

sns.barplot(x='media_type', y='likes', data=grouped_data)

plt.title('likes vs media_type')
plt.xlabel('media_type')
plt.ylabel('Avg. likes received')
plt.show()

# %% [markdown]
# #### While the most posts were photos, Avg. no of likes were higher for videos are much higher.

# %%
grouped_data = df.groupby(['year'])['likes'].mean().reset_index()

sns.barplot(x='year', y='likes', data=grouped_data)

plt.title('likes vs year')
plt.xlabel('year')
plt.ylabel('Avg. likes received')
plt.show()

# %% [markdown]
# ### Avg no. of likes are monotonically increasing with respect to year, may be due to digitalization

# %%
grouped_data = df.groupby(['hour'])['likes'].mean().reset_index() # DataFrame

sns.barplot(x='hour', y='likes', data=grouped_data)
#sns.histplot(x='hour', y='likes', data=grouped_data)

plt.title('likes vs hour')
plt.xlabel('hour')
plt.ylabel('Avg. likes received')
plt.show()

# %%
grouped_data = df.groupby(['month'])['likes'].mean().reset_index()

sns.barplot(x='month', y='likes', data=grouped_data)

plt.title('likes vs month')
plt.xlabel('month')
plt.ylabel('Avg. likes received')
plt.show()

# %% [markdown]
# #### Avg. No of Likes are higher in winters (sep - nov)

# %%
plt.figure(figsize = (16, 6))

grouped_data = df.groupby(['week'])['likes'].mean().reset_index()

sns.barplot(x='week', y='likes', data=grouped_data)

plt.title('likes vs week')
plt.xlabel('week')
plt.ylabel('Avg. likes received')
plt.show()

# %%
plt.figure(figsize = (10, 6))

grouped_data = df.groupby(['day'])['likes'].mean().reset_index()

sns.barplot(x='day', y='likes', data=grouped_data)

plt.title('likes vs day')
plt.xlabel('day')
plt.ylabel('Avg. likes received')
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'date', 'likes', 'content', 'username', 'media',
#        'inferred company', 'media_type', 'content_length', 'stemmed_content',
#        'day', 'week', 'hour', 'month', 'year'],
#       dtype='object')

# %%
grouped_df = df.groupby('username')['likes'].agg(['mean']).sort_values(by = 'mean', ascending = False).reset_index().loc[:10]

plt.figure(figsize=(10, 6))

sns.set_style("whitegrid")
sns.barplot(x='username', y='mean', data=grouped_df)

plt.xlabel('username')
plt.ylabel('Mean Value')
plt.title('Mean and Standard Deviation of Unique Values by username')

plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# SpotifyNews has the maximum variation in the number of likes recieved among the top 10 username to have highest means

# %%
grouped_df = df.groupby('inferred company')['likes'].agg(['mean']).sort_values(by='mean', ascending=False).iloc[:10].reset_index()

plt.figure(figsize=(10, 6))

sns.set_style("whitegrid")
sns.barplot(x='inferred company', y='mean', data=grouped_df)

plt.xlabel('inferred company')
plt.ylabel('Avg. no. of likes')
plt.title('Mean Value for Top 10 Companies')

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# fc barcelona has got the highest number of Average likes..

# %% [markdown]
# ### Multi Variate Analysis

# %%
df.head()
# Out:
#    id                date  likes  \
# 0   1 2020-12-12 00:47:00      1
# 1   2 2018-06-30 10:04:20   2750
# 2   3 2020-09-29 19:47:28     57
# 3   4 2020-10-01 11:40:09    152
# 4   5 2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  spend weekend morning ham egg cheese wrap pair...    TimHortonsPH
# 1  watch rapper mention freestyle hour hyperlink ...       IndyMusic
# 2  canadian armenian community demand ban militar...       CBCCanada
# 3  1st europe devastate covid19 italy redouble ef...  MKWilliamsRome
# 4  congratulation pauletha butts mention present ...           BGISD
#
#                                                media inferred company  \
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 2  [Photo(previewUrl='https://pbs.twimg.com/media...              cbc
# ...

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=df, x='content_length', y='likes', hue='media_type', palette='Set2')

plt.xlabel('content length')
plt.ylabel('likes')
plt.title('Variation of likes')
plt.legend(title='Category')

plt.show()

# %% [markdown]
# Content length normally varies from 0 to 300 words

# %% [markdown]
# And the plot is heavily crowded in 0-100000 likes range.

# %%
grouped_df = df[df['inferred company'].isin(['fc barcelona', 'stryker', 'tesla', 'gucci', 'spotify'])]

plt.figure(figsize=(8, 6))

sns.scatterplot(data=grouped_df, x='content_length', y='likes', hue='inferred company', palette='Set2')

plt.xlabel('content length')
plt.ylabel('likes')
plt.title('Variation of likes')
plt.legend(title='Category')

plt.show()

# %%
grouped_df = df[df['username'].isin(['SpotifyNews', 'RedBullSalzburg', 'pumakorea', 'offclASTRO', 'MichelleHux'])]

plt.figure(figsize=(8, 6))

sns.scatterplot(data=grouped_df, x='content_length', y='likes', hue='username', palette='Set2')

plt.xlabel('content length')
plt.ylabel('likes')
plt.title('Variation of likes')
plt.legend(title='Category')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

for category, color in zip(df['year'].unique(), ['r', 'g', 'b']):
    category_data = df[df['year'] == category]
    ax.scatter(category_data['content_length'], category, category_data['likes'], c=color, label=category)

ax.set_xlabel('content_length')
ax.set_ylabel('year')
ax.set_zlabel('likes')
ax.set_title('3D Scatter Plot')

yticks = np.arange(2019,2023,1)
ax.set_yticks(yticks)

# Show legend
ax.legend()

plt.show()

# %% [markdown]
# There is a significant increase in the number of post having more than 200000 likes in 2021

# %% [markdown]
# Outliers are present in high number in the given data, and they are very significant in 2021

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

index = 1
for category, color in zip(df['media_type'].unique(), ['r', 'g', 'b']):
    category_data = df[df['media_type'] == category]
    ax.scatter(category_data['content_length'], index, category_data['likes'], c=color, label=category)
    index += 1

ax.set_xlabel('content_length')
ax.set_ylabel('media_type')
ax.set_zlabel('likes')
ax.set_title('3D Scatter Plot')

yticks = np.arange(1, 4, 1)
ax.set_yticks(yticks)
ax.set_yticklabels(df['media_type'].unique())

# Show legend
ax.legend()

plt.show()

# %% [markdown]
# ###Word-to-Vec

# %%
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import gensim.downloader as api

# %%
stop_words = set(stopwords.words('english'))
df['tokenized_text'] = df['content'].apply(lambda x: [w.lower() for w in word_tokenize(x) if w.isalpha() and w.lower() not in stop_words])

# %%
model = Word2Vec(df['tokenized_text'], vector_size=100, window=5, min_count=1, workers=2)

# %%
def text_to_vector(text):
    tokens = [w.lower() for w in word_tokenize(text) if w.isalpha() and w.lower() not in stop_words]
    vector = sum([model.wv[word] for word in tokens if word in model.wv])
    return vector.tolist() if vector.any() else [0] * model.vector_size

# %%
df['text_vectors'] = df['content'].apply(text_to_vector)

# %%
df.head()
# Out:
#    id                date  likes  \
# 0   1 2020-12-12 00:47:00      1
# 1   2 2018-06-30 10:04:20   2750
# 2   3 2020-09-29 19:47:28     57
# 3   4 2020-10-01 11:40:09    152
# 4   5 2018-10-19 14:30:46     41
#
#                                              content        username  \
# 0  spend weekend morning ham egg cheese wrap pair...    TimHortonsPH
# 1  watch rapper mention freestyle hour hyperlink ...       IndyMusic
# 2  canadian armenian community demand ban militar...       CBCCanada
# 3  1st europe devastate covid19 italy redouble ef...  MKWilliamsRome
# 4  congratulation pauletha butts mention present ...           BGISD
#
#                                                media inferred company  \
# 0  [Photo(previewUrl='https://pbs.twimg.com/media...      tim hortons
# 1  [Photo(previewUrl='https://pbs.twimg.com/media...      independent
# 2  [Photo(previewUrl='https://pbs.twimg.com/media...              cbc
# ...

# %%
df['text_vectors'][0]
# Out:
# [-6.716573238372803,
#  13.597526550292969,
#  6.612761497497559,
#  3.521379232406616,
#  17.622730255126953,
#  -4.319509506225586,
#  4.110110282897949,
#  10.550518035888672,
#  -5.106707572937012,
#  -4.339517593383789,
#  3.9968769550323486,
#  -28.941545486450195,
#  -2.716895818710327,
#  -0.5816560983657837,
#  2.8224081993103027,
#  6.723069190979004,
#  -0.577934980392456,
#  -2.9009830951690674,
#  2.2231879234313965,
#  -14.536137580871582,
#  -4.386223316192627,
#  6.329773426055908,
#  6.549839019775391,
#  -1.4435324668884277,
#  0.22314928472042084,
#  10.202296257019043,
#  -11.549113273620605,
#  -6.813121318817139,
#  -4.154064178466797,
#  2.244948148727417,
#  2.354743003845215,
#  -4.239274501800537,
#  5.697310924530029,
#  4.119232177734375,
#  -11.73021125793457,
#  8.221516609191895,
#  2.3110156059265137,
#  -7.32700252532959,
#  -12.430459976196289,
#  -22.852989196777344,
#  -0.10663381218910217,
#  -9.636713981628418,
#  -6.138075828552246,
# ...

# %% [markdown]
# ###Downloading the images

# %%
def extract_urls(link):

  if link.find('Photo') != -1 :
    start_index = link.find("previewUrl='") + len("previewUrl='")
    end_index = link.find("'", start_index)
    media_url = link[start_index:end_index]

  if link.find('Video') != -1 :
    start_index = link.find("thumbnailUrl='") + len("thumbnailUrl='")
    end_index = link.find("'", start_index)
    media_url = link[start_index:end_index]

  if link.find('Gif') != -1 :
    start_index = link.find("thumbnailUrl='") + len("thumbnailUrl='")
    end_index = link.find("'", start_index)
    media_url = link[start_index:end_index]


  return media_url

# %%
df['media_url'] = df['media'].apply(lambda link: extract_urls(link))
df['media_url'].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-88dac7ec304e> in <cell line: 1>()
# ----> 1 df['media_url'] = df['media'].apply(lambda link: extract_urls(link))
#       2 df['media_url'].head()
#
# NameError: name 'df' is not defined

# %%
from transformers import CLIPProcessor, CLIPModel

# Loading CLIP model and processor

model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# ...

# %%
def caption_image(url):

    image_data = requests.get(url).content
    image = Image.open(BytesIO(image_data))

    inputs = processor(text=["a photo of a "], images=image, return_tensors="pt", padding=True)

    outputs = model(**inputs)
    logits_per_image = outputs.logits_per_image
    probs = logits_per_image.softmax(dim=1)

    predicted_class = probs.argmax(1).item()
    predicted_caption = processor.decode(predicted_class)

    return predicted_caption

# %%
df['image_captions'] = df[df['media_type'] == 'Photo']['media_url'].apply(lambda text : caption_image(text))
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-107-defc7c0db598> in <cell line: 1>()
# ----> 1 df['image_captions'] = df[df['media_type'] == 'Photo']['media_url'].apply(lambda text : caption_image(text))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4628         dtype: float64
#    4629         """
# -> 4630         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4631
#    4632     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1023
#    1024         # self.f is Callable
# -> 1025         return self.apply_standard()
#    1026
#    1027     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1074             else:
# ...

# %%
image_data = requests.get(df[df['media_type'] == 'Photo'].loc[0]['media_url']).content

# %%
img_stream = BytesIO(image_data)
img_stream

# %%
from PIL import Image

# %%
image = Image.open(img_stream)

# Display or process the image as needed
image.show()

# %%
image.show()

# %% [markdown]
# ###Summary and Conclusion

# %% [markdown]
# The Exploratory Data Analysis (EDA) was performed on a Twitter dataset focusing on ads-related data.

# %% [markdown]
#  We found out that 'likes' column is heavily weighted towards higher numbers

# %% [markdown]
# The likes does not have very significant correlation with content length, rather it depends a lot on the sematics of the content

# %% [markdown]
# The likes depend heavily on media_type and the vedios have the highest average number of likes despite photo being the highly posted media type

# %% [markdown]
# We converted content to vec using word-to-vec

# %% [markdown]
# We also tried to find the dependence of 'likes' with the content in the media using object detection.
